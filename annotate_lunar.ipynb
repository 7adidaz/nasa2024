# %%
from ultralytics import YOLO
import torch
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

model = YOLO(r"C:\\Users\\moaaz\\Desktop\\space_apps\\data\\lunar\\best.pt").to(device='cpu')

# Run inference with a confidence threshold of 50%
res = []
for i in range(76):
    res.append(f'lunarplots\lunar_plot{i}.png')
# Out:
# <>:10: SyntaxWarning: invalid escape sequence '\l'
# <>:10: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\moaaz\AppData\Local\Temp\ipykernel_20788\2814711607.py:10: SyntaxWarning: invalid escape sequence '\l'
#   res.append(f'lunarplots\lunar_plot{i}.png')

# %%
model.predict(source ="lunarplots/" , save = True , conf=0.5 , project = 'lunarannotations' , name='annotation' , iou =0.5)
# Out:
# image 1/76 c:\Users\moaaz\Desktop\space_apps\data\lunar\lunarplots\lunar_plot0.png: 192x256 1 Event, 200.3ms
# image 2/76 c:\Users\moaaz\Desktop\space_apps\data\lunar\lunarplots\lunar_plot1.png: 192x256 1 Event, 151.2ms
# image 3/76 c:\Users\moaaz\Desktop\space_apps\data\lunar\lunarplots\lunar_plot10.png: 192x256 1 Event, 147.1ms
# image 4/76 c:\Users\moaaz\Desktop\space_apps\data\lunar\lunarplots\lunar_plot11.png: 192x256 1 Event, 162.9ms
# image 5/76 c:\Users\moaaz\Desktop\space_apps\data\lunar\lunarplots\lunar_plot12.png: 192x256 (no detections), 152.9ms
# image 6/76 c:\Users\moaaz\Desktop\space_apps\data\lunar\lunarplots\lunar_plot13.png: 192x256 1 Event, 157.0ms
# image 7/76 c:\Users\moaaz\Desktop\space_apps\data\lunar\lunarplots\lunar_plot14.png: 192x256 1 Event, 153.2ms
# image 8/76 c:\Users\moaaz\Desktop\space_apps\data\lunar\lunarplots\lunar_plot15.png: 192x256 1 Event, 176.5ms
# ...

# %%
# Out:
# ultralytics.engine.results.Results
